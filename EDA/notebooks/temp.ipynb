# %% [markdown]
# # Import Libraries

# %%
import pandas as pd

# %% [markdown]
# # Load Source Data

# %%
src_games = pd.read_csv('../data/source_data/games.csv')
src_turns = pd.read_csv('../data/source_data/turns.csv')
src_train = pd.read_csv('../data/source_data/train.csv')
src_test = pd.read_csv('../data/source_data/test.csv')

# %% [markdown]
# # Load Data With Rack Usage Feature

# %%
prc_games = pd.read_csv('../data/preprocessed_data/new_games.csv')
prc_turns = pd.read_csv('../data/preprocessed_data/new_turns.csv')
prc_train = pd.read_csv('../data/preprocessed_data/new_train.csv')
prc_test = pd.read_csv('../data/preprocessed_data/new_test.csv')

# %% [markdown]
# # Load Cleaned Data

# %%
cleaned_train = pd.read_csv('../data/cleaned_data/cleaned_train.csv')
cleaned_test = pd.read_csv('../data/cleaned_data/cleaned_test.csv')

# %% [markdown]
# # Split datasets to users_dataset and bots_dataset on train only

# %%
bots = ['BetterBot', 'STEEBot', 'HastyBot']

# %%
user_df = src_train[~src_train["nickname"].isin(bots)] 
user_df = user_df.rename(
    columns={"nickname": "user_name", "score": "user_score", "rating": "user_rating"}
) 

bot_df = src_train[src_train["nickname"].isin(bots)]

bot_df = bot_df.rename(
    columns={"nickname": "bot_name", "score": "bot_score", "rating": "bot_rating"}
)

# %% [markdown]
# # Some Analyses and Test

# %%
prc_turns.head()
# Out:
#    game_id  turn_number   nickname     rack location      move  points  score  \
# 0        1            1  BetterBot  DDEGITT       8G       DIG      10     10
# 1        1            2      stevy  AEHOPUX       7H       HAP      18     18
# 2        1            3  BetterBot  DEELTTU       6I      LUTE      16     26
# 3        1            4      stevy  EMORSUX       5K        UM      16     34
# 4        1            5  BetterBot  ACDEITU       L5  ..DICATE      28     54
#
#   turn_type  rack_len  rack_usage
# 0      Play       7.0    0.428571
# 1      Play       7.0    0.428571
# 2      Play       7.0    0.571429
# 3      Play       7.0    0.285714
# 4      Play       7.0    0.857143

# %%
prc_games.head()
# Out:
#    game_id      first time_control_name game_end_reason  winner  \
# 0        1  BetterBot           regular        STANDARD       1
# 1        2      Super           regular        STANDARD       1
# 2        3  BetterBot           regular        STANDARD       1
# 3        4  BetterBot           regular        RESIGNED       0
# 4        5    STEEBot           regular        STANDARD       0
#
#          created_at lexicon  initial_time_seconds  increment_seconds  \
# 0   08/26/2022 3:38   NWL20                  1200                  0
# 1  08/10/2022 19:19   CSW21                  3600                  0
# 2   09/04/2022 8:04   CSW21                   900                  0
# 3   09/12/2022 2:36   CSW21                  3600                  0
# 4   09/06/2022 4:31   NWL20                  1200                  0
#
#   rating_mode  max_overtime_minutes  game_duration_seconds bot_nickname  \
# 0      CASUAL                     1             674.844274    BetterBot
# ...

# %%
prc_train.head()
# Out:
#    game_id        nickname  score  mean_rack_usage  rating
# 0        1       BetterBot    335         0.596154    1637
# 1        1           stevy    429         0.457143    1500
# 2        3       davidavid    440         0.469388    1811
# 3        3       BetterBot    318         0.538462    2071
# 4        4  Inandoutworker    119         0.285714    1473

# %%
prc_turns.head()
# Out:
#    game_id  turn_number   nickname     rack location      move  points  score  \
# 0        1            1  BetterBot  DDEGITT       8G       DIG      10     10
# 1        1            2      stevy  AEHOPUX       7H       HAP      18     18
# 2        1            3  BetterBot  DEELTTU       6I      LUTE      16     26
# 3        1            4      stevy  EMORSUX       5K        UM      16     34
# 4        1            5  BetterBot  ACDEITU       L5  ..DICATE      28     54
#
#   turn_type  rack_len  rack_usage
# 0      Play       7.0    0.428571
# 1      Play       7.0    0.428571
# 2      Play       7.0    0.571429
# 3      Play       7.0    0.285714
# 4      Play       7.0    0.857143

# %%
prc_games.head()
# Out:
#    game_id      first time_control_name game_end_reason  winner  \
# 0        1  BetterBot           regular        STANDARD       1
# 1        2      Super           regular        STANDARD       1
# 2        3  BetterBot           regular        STANDARD       1
# 3        4  BetterBot           regular        RESIGNED       0
# 4        5    STEEBot           regular        STANDARD       0
#
#          created_at lexicon  initial_time_seconds  increment_seconds  \
# 0   08/26/2022 3:38   NWL20                  1200                  0
# 1  08/10/2022 19:19   CSW21                  3600                  0
# 2   09/04/2022 8:04   CSW21                   900                  0
# 3   09/12/2022 2:36   CSW21                  3600                  0
# 4   09/06/2022 4:31   NWL20                  1200                  0
#
#   rating_mode  max_overtime_minutes  game_duration_seconds bot_nickname  \
# 0      CASUAL                     1             674.844274    BetterBot
# ...
