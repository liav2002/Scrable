# %% [markdown]
# # Import Libraries

# %%
import pandas as pd

# %% [markdown]
# # Load Data for False Analysis

# %%
df = pd.read_csv('../../output/false_analysis_df/false_analysis.csv')

# %%
df.tail()
# Out:
#        game_id  bot_score  bot_rating  user_score  user_mean_rack_usage  \
# 50405    44620        447        2151         430              0.680672
# 50406      336        573        2255         322              0.683117
# 50407    59460        347        1614         406              0.598319
# 50408     8333        458        1788         348              0.595238
# 50409    43220        437        1862         406              0.514286
#
#        mean_average_letter_score  bot_difficulty  is_first_play  \
# 50405                   1.599860               2              1
# 50406                   1.736364               3              0
# 50407                   1.433824               3              1
# 50408                   1.652778               2              1
# 50409                   1.650794               2              1
#
#        negative_end_reason  lexicon_encoded  game_end_reason_encoded  \
# 50405                    0                0                        2
# ...
